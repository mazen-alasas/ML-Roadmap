# %%
import numpy as np
import random
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.animation import FuncAnimation
from datetime import datetime, timedelta
from itertools import count

# %%
dates = [
    datetime(2019, 5, 24),
    datetime(2019, 5, 25),
    datetime(2019, 5, 26),
    datetime(2019, 5, 27),
    datetime(2019, 5, 28),
    datetime(2019, 5, 29),
    datetime(2019, 5, 30)
]


y = [0, 1, 3, 4, 6, 5, 7]
plt.plot_date(dates, y, linestyle = '-')

# %%
plt.plot_date(dates, y, linestyle = 'solid')
plt.gcf().autofmt_xdate()

# %%
date_format = mdates.DateFormatter('%b, %d, %Y')

plt.plot_date(dates, y, linestyle = 'solid')
plt.gcf().autofmt_xdate()
plt.gca().xaxis.set_major_formatter(date_format)
plt.show()

# %%
data = pd.read_csv('data 5.csv')
price_date = data['Date']
price_close = data['Close']

# %%
plt.plot_date(price_date, price_close, linestyle = 'solid')

# %%
date_format = mdates.DateFormatter('%b, %d, %Y')

plt.plot_date(price_date, price_close, linestyle = 'solid')
plt.gcf().autofmt_xdate()
plt.show()

# %%
# sort by date if it not sorted by pandas 
data['Date'] = pd.to_datetime(data['Date'])
data.sort_values('Date', inplace = True)

# %%
x_vals = []
y_vals = []

index = count()

def animate(i):
    x_vals.append(next(index))
    y_vals.append(random.randint(0, 10))
    plt.plot(x_vals, y_vals)

ani = FuncAnimation(plt.gcf(), animate, interval = 1000) # in millisecond
# Out:
# C:\Users\mazen\AppData\Local\Temp\ipykernel_5856\1833860277.py:11: UserWarning: frames=None which we can infer the length of, did not pass an explicit *save_count* and passed cache_frame_data=True.  To avoid a possibly unbounded cache, frame data caching has been disabled. To suppress this warning either pass `cache_frame_data=False` or `save_count=MAX_FRAMES`.
#   ani = FuncAnimation(plt.gcf(), animate, interval = 1000) # in millisecond

# %%
data = pd.read_csv('data 2.csv')
ages = data['Age']
dev_salaries = data['All_Devs']
py_salaries = data['Python']
js_salaries = data['JavaScript']


plt.plot(ages, py_salaries, label = 'Python')
plt.plot(ages, js_salaries, label = 'javascript')
plt.plot(ages, dev_salaries, label = 'all devs')


plt.legend()
plt.show()

# %%
# using subplots

plt.subplot(2, 2, 1)
plt.plot(ages, py_salaries, label = 'Python')
plt.legend()

plt.subplot(2, 2, 2)
plt.plot(ages, js_salaries, label = 'javascript')
plt.legend()

plt.subplot(2, 2, 3)
plt.plot(ages, dev_salaries, label = 'all devs')
plt.legend()

plt.tight_layout()
plt.show()

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows = 2, ncols = 2, 
                                             figsize = (10, 5), 
                                             sharex = True,
                                             sharey = True)                                         


ax1.plot(ages, py_salaries, label = 'Python')
ax2.plot(ages, js_salaries, label = 'javascript')
ax3.plot(ages, dev_salaries, label = 'all devs')

ax1.legend()
ax2.legend()
ax3.legend()

plt.show()
