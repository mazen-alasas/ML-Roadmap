# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

# %%
np.random.seed(42)

X, y = make_blobs(n_samples    = 500, 
                  centers      = 4,
                  n_features = 2,
                  shuffle      = True,
                  random_state = 40)

cluster = len(np.unique(y)) 
kmean_model = KMeans(n_clusters = cluster, max_iter = 150)
kmean_model.fit(X)

y_pred = kmean_model.predict(X)
# Out:
# c:\Users\mazen\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(

# %%
df = pd.DataFrame(dict(x = X[:, 0], y = X[:, 1], label = y_pred))
df.head(10)
# Out:
#           x         y  label
# 0 -4.710204 -8.200208      0
# 1  0.909620  2.078220      1
# 2 -0.193633 -3.541595      3
# 3  5.340721 -3.679075      2
# 4 -0.158472 -9.939293      0
# 5  0.634796  1.830192      1
# 6  5.285100 -5.233614      2
# 7 -1.512305 -4.460829      3
# 8 -3.139489 -4.199506      3
# 9  5.208240 -3.457637      2

# %%
plt.figure(figsize = (10, 8))
plt.scatter(df['x'], df['y'], c = df['label'])
plt.scatter(kmean_model.cluster_centers_[:, 0], kmean_model.cluster_centers_[:, 1], marker = 'x', s = 100, c = 'k', linewidths = 3)
